# %%
import pandas as pd
import os
import shutil

# %% [markdown]
# Code we used:
# https://www.kaggle.com/datasets/paultimothymooney/chest-xray-pneumonia
# https://github.com/ieee8023/covid-chestxray-dataset

# %%
# Get data for positive covid samples
FILE_PATH = "Datasets/metadata.csv"
IMAGES_PATH = "Datasets/covid/images"

# %%
covid_data = pd.read_csv(FILE_PATH)
print(covid_data.shape)
# Out:
# (950, 30)

# %%
covid_data.head()
# Out:
#   patientid  offset sex   age                   finding RT_PCR_positive  \
# 0         2     0.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 1         2     3.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 2         2     5.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 3         2     6.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 4         4     0.0   F  52.0  Pneumonia/Viral/COVID-19               Y
#
#   survival intubated intubation_present went_icu  ...              date  \
# 0        Y         N                  N        N  ...  January 22, 2020
# 1        Y         N                  N        N  ...  January 25, 2020
# 2        Y         N                  N        N  ...  January 27, 2020
# 3        Y         N                  N        N  ...  January 28, 2020
# 4      NaN         N                  N        N  ...  January 25, 2020
#
#                                             location  folder  \
# ...

# %%
TARGET_DIR = "Datasets/covid_data"
if not os.path.exists(TARGET_DIR):
    os.mkdir(TARGET_DIR)
    print("covid folder created")
# Out:
# covid folder created

# %%
count = 0
for(i,row) in covid_data.iterrows():
    if (row["finding"]=="Pneumonia/Viral/COVID-19") and row["view"]=="PA": #PA means frontview of X-RAY
        filename = row["filename"]
        image_path = os.path.join(IMAGES_PATH,filename)
        image_copy_path = os.path.join(TARGET_DIR, filename)
        shutil.copy2(image_path,image_copy_path)
        print("moving image",count)
        count+=1
        
print(count)
# Out:
# moving image 0
# moving image 1
# moving image 2
# moving image 3
# moving image 4
# moving image 5
# moving image 6
# moving image 7
# moving image 8
# moving image 9
# moving image 10
# moving image 11
# moving image 12
# moving image 13
# moving image 14
# moving image 15
# moving image 16
# moving image 17
# moving image 18
# moving image 19
# moving image 20
# moving image 21
# moving image 22
# moving image 23
# moving image 24
# moving image 25
# moving image 26
# moving image 27
# moving image 28
# moving image 29
# moving image 30
# moving image 31
# moving image 32
# moving image 33
# moving image 34
# moving image 35
# moving image 36
# moving image 37
# moving image 38
# moving image 39
# moving image 40
# moving image 41
# moving image 42
# moving image 43
# moving image 44
# moving image 45
# moving image 46
# moving image 47
# moving image 48
# moving image 49
# moving image 50
# moving image 51
# moving image 52
# moving image 53
# moving image 54
# moving image 55
# ...

# %%
count = 0
for(i,row) in covid_data.iterrows():
    if (row["finding"]=="Pneumonia/Viral/COVID-19") and row["view"]=="PA": #PA means frontview of X-RAY
        filename = row["filename"]
        image_path = os.path.join(IMAGES_PATH,filename)
        image_copy_path = os.path.join(TARGET_DIR, filename)
        shutil.copy2(image_path,image_copy_path)
        count+=1
        
print(count)
# Out:
# 196

# %%
# Sampling Healthy X-Ray Images
import random
KAGGLE_FILE_PATH = "Datasets/chest_xray/train/NORMAL"
TARGET_HEALTHY_DIR = "Datasets/healthy_data"
if not os.path.exists(TARGET_HEALTHY_DIR):
    os.mkdir(TARGET_HEALTHY_DIR)
    print("healthy_data created")
# Out:
# healthy_data created

# %%
image_names = os.listdir(KAGGLE_FILE_PATH)

# %%
image_names
# Out:
# ['.DS_Store',
#  'IM-0115-0001.jpeg',
#  'IM-0117-0001.jpeg',
#  'IM-0119-0001.jpeg',
#  'IM-0122-0001.jpeg',
#  'IM-0125-0001.jpeg',
#  'IM-0127-0001.jpeg',
#  'IM-0128-0001.jpeg',
#  'IM-0129-0001.jpeg',
#  'IM-0131-0001.jpeg',
#  'IM-0133-0001.jpeg',
#  'IM-0135-0001.jpeg',
#  'IM-0137-0001.jpeg',
#  'IM-0140-0001.jpeg',
#  'IM-0141-0001.jpeg',
#  'IM-0143-0001.jpeg',
#  'IM-0145-0001.jpeg',
#  'IM-0147-0001.jpeg',
#  'IM-0149-0001.jpeg',
#  'IM-0151-0001.jpeg',
#  'IM-0152-0001.jpeg',
#  'IM-0154-0001.jpeg',
#  'IM-0156-0001.jpeg',
#  'IM-0158-0001.jpeg',
#  'IM-0160-0001.jpeg',
#  'IM-0162-0001.jpeg',
#  'IM-0164-0001.jpeg',
#  'IM-0166-0001.jpeg',
#  'IM-0168-0001.jpeg',
#  'IM-0170-0001.jpeg',
#  'IM-0172-0001.jpeg',
#  'IM-0176-0001.jpeg',
#  'IM-0177-0001.jpeg',
#  'IM-0178-0001.jpeg',
#  'IM-0180-0001.jpeg',
#  'IM-0182-0001.jpeg',
#  'IM-0183-0001.jpeg',
#  'IM-0185-0001.jpeg',
#  'IM-0187-0001.jpeg',
#  'IM-0189-0001.jpeg',
#  'IM-0191-0001.jpeg',
#  'IM-0193-0001.jpeg',
# ...

# %%
random.shuffle(image_names)

# %%
for i in range(196):
    image_name = image_names[i]
    image_path = os.path.join(KAGGLE_FILE_PATH, image_name)
    
    target_path = os.path.join(TARGET_HEALTHY_DIR, image_name)
    
    shutil.copy2(image_path, target_path)

# %% [markdown]
# ## Separating into train and test dir by creating a new folder as followed below

# %%
COVID_FILE_PATH = "Datasets/covid_data"
TARGET_COVID_TRAIN_DIR = "Datasets/final_data/train/covid"
TARGET_COVID_TEST_DIR = "Datasets/final_data/test/covid"

HEALTHY_FILE_PATH = "Datasets/healthy_data"
TARGET_HEALTHY_TRAIN_DIR = "Datasets/final_data/train/normal" 
TARGET_HEALTHY_TEST_DIR = "Datasets/final_data/test/normal"

# %%
covid_image_names = os.listdir(COVID_FILE_PATH)
healthy_image_names = os.listdir(HEALTHY_FILE_PATH)

#GETTING TEST DATA
for i in range(39):
    #COVID TEST DATA
    covid_image_name = covid_image_names[i]
    covid_image_path = os.path.join(COVID_FILE_PATH, covid_image_name)
    
    covid_test_target_path = os.path.join(TARGET_COVID_TEST_DIR, covid_image_name)
    
    shutil.copy2(covid_image_path, covid_test_target_path)
    
    #HEALTHY TEST DATA
    healthy_image_name = healthy_image_names[i]
    healthy_image_path = os.path.join(HEALTHY_FILE_PATH, healthy_image_name)
    
    healthy_test_target_path = os.path.join(TARGET_HEALTHY_TEST_DIR, healthy_image_name)
    
    shutil.copy2(healthy_image_path, healthy_test_target_path)
    
#GETTING TRAIN DATA
for i in range(39,196):
    #COVID TRAIN DATA
    covid_image_name = covid_image_names[i]
    covid_image_path = os.path.join(COVID_FILE_PATH, covid_image_name)
    
    covid_train_target_path = os.path.join(TARGET_COVID_TRAIN_DIR, covid_image_name)
    
    shutil.copy2(covid_image_path, covid_train_target_path)
    
    #HEALTHY TEST DATA
    healthy_image_name = healthy_image_names[i]
    healthy_image_path = os.path.join(HEALTHY_FILE_PATH, healthy_image_name)
    
    healthy_train_target_path = os.path.join(TARGET_HEALTHY_TRAIN_DIR, healthy_image_name)
    
    shutil.copy2(healthy_image_path, healthy_train_target_path)
